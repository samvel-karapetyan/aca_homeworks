# %% [markdown]
# # PyTorch implementation

# %% [markdown]
# We include this file for understanding how we got resnet50_torch.pth.
#
# Note: For training we used big_train_data_1008 and our model didn't see data from "data/images" and others from drive.

# %%
import os
import torch
from torch import nn
from torchvision.models import resnet50, ResNet50_Weights
from torch.utils.data import DataLoader
from torch.utils.data import Dataset
from torchvision.datasets import ImageFolder
from torchvision.transforms import Lambda
import torchvision.transforms as transforms

# Check if CUDA is available, otherwise use CPU
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# Define the labels for the classes
labels = {
    0: "dog", 
    1: "horse",
    2: "elephant",
    3: "butterfly",
    4: "rooster",
    5: "cat",
    6: "cow",
    7: "sheep",
    8: "spider",
    9: "squirrel"
}

# %%
path_train = ""  # This path shows the train data

# Specify the weights to use for the pre-processing transformation
weights = ResNet50_Weights.DEFAULT

# Get the pre-processing transformation for the model
preprocess = weights.transforms()

# Create an ImageFolder dataset for the training data
data_train = ImageFolder(
    root=path_train,
    transform=preprocess,
    target_transform=Lambda(lambda y: torch.zeros(10, dtype=torch.float).scatter_(0, torch.tensor(y), value=1)) # like O-H-E our labels
)

# Create a dataloader for the training data
train_dataloader = DataLoader(data_train, batch_size=128, shuffle=True)

# %%
# Load the pre-trained ResNet-50 model
model = resnet50(weights="IMAGENET1K_V2")

for param in model.parameters():
    param.requires_grad = False

num_classes = 10

# Replace the fully connected layer of the model with a new sequential layer
model.fc = nn.Sequential(
    nn.Linear(2048, 100), # 2048 - shape after ResNet50's average pooling
    nn.ReLU(),
    nn.Linear(100, 10) # 10 - number of our classes
    )

model.train()  # Set the model to training mode
model.to(device)  # Move the model to the specified device (CPU or GPU)

criterion = nn.CrossEntropyLoss()  # Define the loss function
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)  # Define the optimizer

# Training loop
for epoch in range(5): # We did just 5 epochs
    for i, (images, labels) in enumerate(train_dataloader):
        images = images.to(device)  # Move the input images to the specified device
        labels = labels.to(device)  # Move the labels to the specified device

        optimizer.zero_grad()  # Zero the gradients

        output = model(images)  # Forward pass

        _, output_predict = torch.max(output, 1)  # Get the predicted labels 
        _, label_predict = torch.max(labels, 1)  # Get the ground-truth labels
        # _ - max value, output_predict and label_predict - indeces 

        accuracy = torch.mean(output_predict == label_predict, dtype=torch.float).item()  # Calculate accuracy
        loss = criterion(output, labels)  # Calculate the loss

        loss.backward()  # Backward pass (compute gradients)
        optimizer.step()  # Update model parameters

        # Print the current iteration's loss and accuracy
        print(f"Epoch {epoch+1}, Iteration {i+1}: Loss = {loss.item()}: Accuracy = {accuracy},")

torch.save(model.state_dict(), "resnet50.pth")
# Out:
# Epoch 1, Iteration 1: Loss = 2.3279340267181396: Accuracy = 0.0546875,
# Epoch 1, Iteration 2: Loss = 2.230929136276245: Accuracy = 0.3984375,
# Epoch 1, Iteration 3: Loss = 2.133934736251831: Accuracy = 0.6171875,
# Epoch 1, Iteration 4: Loss = 2.0644583702087402: Accuracy = 0.6484375,
# Epoch 1, Iteration 5: Loss = 1.924604892730713: Accuracy = 0.8125,
# Epoch 1, Iteration 6: Loss = 1.8178476095199585: Accuracy = 0.8203125,
# Epoch 1, Iteration 7: Loss = 1.7037529945373535: Accuracy = 0.890625,
# Epoch 1, Iteration 8: Loss = 1.6186394691467285: Accuracy = 0.890625,
# Epoch 1, Iteration 9: Loss = 1.4860680103302002: Accuracy = 0.875,
# Epoch 1, Iteration 10: Loss = 1.3224585056304932: Accuracy = 0.875,
# Epoch 1, Iteration 11: Loss = 1.2022466659545898: Accuracy = 0.9140625,
# Epoch 1, Iteration 12: Loss = 1.202772855758667: Accuracy = 0.890625,
# Epoch 1, Iteration 13: Loss = 1.0467451810836792: Accuracy = 0.8984375,
# Epoch 1, Iteration 14: Loss = 0.9276514053344727: Accuracy = 0.921875,
# Epoch 1, Iteration 15: Loss = 0.879031240940094: Accuracy = 0.921875,
# Epoch 1, Iteration 16: Loss = 0.8694525957107544: Accuracy = 0.8984375,
# Epoch 1, Iteration 17: Loss = 0.828162431716919: Accuracy = 0.921875,
# Epoch 1, Iteration 18: Loss = 0.713026762008667: Accuracy = 0.953125,
# Epoch 1, Iteration 19: Loss = 0.7558350563049316: Accuracy = 0.9140625,
# Epoch 1, Iteration 20: Loss = 0.6699222326278687: Accuracy = 0.9140625,
# Epoch 1, Iteration 21: Loss = 0.5431225895881653: Accuracy = 0.9453125,
# Epoch 1, Iteration 22: Loss = 0.5552589297294617: Accuracy = 0.9296875,
# Epoch 1, Iteration 23: Loss = 0.49221643805503845: Accuracy = 0.9453125,
# Epoch 1, Iteration 24: Loss = 0.4737055003643036: Accuracy = 0.9296875,
# Epoch 1, Iteration 25: Loss = 0.42790305614471436: Accuracy = 0.9296875,
# Epoch 1, Iteration 26: Loss = 0.4256841242313385: Accuracy = 0.921875,
# Epoch 1, Iteration 27: Loss = 0.419635146856308: Accuracy = 0.921875,
# Epoch 1, Iteration 28: Loss = 0.3692205250263214: Accuracy = 0.9609375,
# Epoch 1, Iteration 29: Loss = 0.32905223965644836: Accuracy = 0.9296875,
# Epoch 1, Iteration 30: Loss = 0.25273215770721436: Accuracy = 0.96875,
# Epoch 1, Iteration 31: Loss = 0.3030073344707489: Accuracy = 0.9296875,
# Epoch 1, Iteration 32: Loss = 0.28243404626846313: Accuracy = 0.953125,
# Epoch 1, Iteration 33: Loss = 0.3432313799858093: Accuracy = 0.9140625,
# Epoch 1, Iteration 34: Loss = 0.2450842410326004: Accuracy = 0.96875,
# Epoch 1, Iteration 35: Loss = 0.2587101459503174: Accuracy = 0.9375,
# Epoch 1, Iteration 36: Loss = 0.1942121684551239: Accuracy = 0.96875,
# Epoch 1, Iteration 37: Loss = 0.18640436232089996: Accuracy = 0.953125,
# Epoch 1, Iteration 38: Loss = 0.2516034245491028: Accuracy = 0.9453125,
# Epoch 1, Iteration 39: Loss = 0.17681074142456055: Accuracy = 0.9765625,
# Epoch 1, Iteration 40: Loss = 0.19942791759967804: Accuracy = 0.953125,
# Epoch 1, Iteration 41: Loss = 0.2759703993797302: Accuracy = 0.921875,
# Epoch 1, Iteration 42: Loss = 0.0992414802312851: Accuracy = 1.0,
# Epoch 1, Iteration 43: Loss = 0.1747768521308899: Accuracy = 0.9609375,
# Epoch 1, Iteration 44: Loss = 0.19026735424995422: Accuracy = 0.953125,
# Epoch 1, Iteration 45: Loss = 0.23524990677833557: Accuracy = 0.9140625,
# Epoch 1, Iteration 46: Loss = 0.17365089058876038: Accuracy = 0.96875,
# Epoch 1, Iteration 47: Loss = 0.1728527992963791: Accuracy = 0.9609375,
# Epoch 1, Iteration 48: Loss = 0.2081185132265091: Accuracy = 0.9296875,
# Epoch 1, Iteration 49: Loss = 0.1486974060535431: Accuracy = 0.9609375,
# Epoch 1, Iteration 50: Loss = 0.20569777488708496: Accuracy = 0.9609375,
# Epoch 1, Iteration 51: Loss = 0.1944355070590973: Accuracy = 0.9609375,
# Epoch 1, Iteration 52: Loss = 0.20731420814990997: Accuracy = 0.9453125,
# Epoch 1, Iteration 53: Loss = 0.16082480549812317: Accuracy = 0.9609375,
# Epoch 1, Iteration 54: Loss = 0.16013038158416748: Accuracy = 0.9765625,
# Epoch 1, Iteration 55: Loss = 0.18939460813999176: Accuracy = 0.953125,
# Epoch 1, Iteration 56: Loss = 0.16072268784046173: Accuracy = 0.953125,
# Epoch 1, Iteration 57: Loss = 0.18579226732254028: Accuracy = 0.9453125,
# Epoch 1, Iteration 58: Loss = 0.1294335573911667: Accuracy = 0.9765625,
# Epoch 1, Iteration 59: Loss = 0.1156318336725235: Accuracy = 0.9765625,
# Epoch 1, Iteration 60: Loss = 0.12053515017032623: Accuracy = 0.9765625,
# Epoch 1, Iteration 61: Loss = 0.11877349019050598: Accuracy = 0.96875,
# Epoch 1, Iteration 62: Loss = 0.16713324189186096: Accuracy = 0.96875,
# Epoch 1, Iteration 63: Loss = 0.18355168402194977: Accuracy = 0.9609375,
# Epoch 1, Iteration 64: Loss = 0.11422030627727509: Accuracy = 0.96875,
# Epoch 1, Iteration 65: Loss = 0.13074776530265808: Accuracy = 0.984375,
# Epoch 1, Iteration 66: Loss = 0.09149539470672607: Accuracy = 0.9765625,
# Epoch 1, Iteration 67: Loss = 0.10575683414936066: Accuracy = 0.9765625,
# Epoch 1, Iteration 68: Loss = 0.15197379887104034: Accuracy = 0.96875,
# Epoch 1, Iteration 69: Loss = 0.09040853381156921: Accuracy = 0.984375,
# Epoch 1, Iteration 70: Loss = 0.0813279002904892: Accuracy = 0.984375,
# Epoch 1, Iteration 71: Loss = 0.21457526087760925: Accuracy = 0.9375,
# Epoch 1, Iteration 72: Loss = 0.1829758882522583: Accuracy = 0.9453125,
# Epoch 1, Iteration 73: Loss = 0.14731217920780182: Accuracy = 0.953125,
# Epoch 1, Iteration 74: Loss = 0.0907326340675354: Accuracy = 0.9765625,
# Epoch 1, Iteration 75: Loss = 0.14071762561798096: Accuracy = 0.953125,
# Epoch 1, Iteration 76: Loss = 0.17116691172122955: Accuracy = 0.9453125,
# Epoch 1, Iteration 77: Loss = 0.18329229950904846: Accuracy = 0.953125,
# Epoch 1, Iteration 78: Loss = 0.17500147223472595: Accuracy = 0.9609375,
# Epoch 1, Iteration 79: Loss = 0.11820170283317566: Accuracy = 0.9791666865348816,
# Epoch 2, Iteration 1: Loss = 0.129718616604805: Accuracy = 0.96875,
# Epoch 2, Iteration 2: Loss = 0.09217631071805954: Accuracy = 0.9921875,
# Epoch 2, Iteration 3: Loss = 0.10762128233909607: Accuracy = 0.96875,
# Epoch 2, Iteration 4: Loss = 0.12560731172561646: Accuracy = 0.9765625,
# Epoch 2, Iteration 5: Loss = 0.11854974925518036: Accuracy = 0.9765625,
# Epoch 2, Iteration 6: Loss = 0.10688888281583786: Accuracy = 0.96875,
# Epoch 2, Iteration 7: Loss = 0.09738472104072571: Accuracy = 0.9765625,
# Epoch 2, Iteration 8: Loss = 0.11534350365400314: Accuracy = 0.96875,
# Epoch 2, Iteration 9: Loss = 0.13024166226387024: Accuracy = 0.9609375,
# Epoch 2, Iteration 10: Loss = 0.05255694314837456: Accuracy = 0.9921875,
# Epoch 2, Iteration 11: Loss = 0.07646043598651886: Accuracy = 0.984375,
# Epoch 2, Iteration 12: Loss = 0.07466268539428711: Accuracy = 0.984375,
# Epoch 2, Iteration 13: Loss = 0.15809957683086395: Accuracy = 0.9453125,
# Epoch 2, Iteration 14: Loss = 0.06298799067735672: Accuracy = 0.984375,
# Epoch 2, Iteration 15: Loss = 0.09382811933755875: Accuracy = 0.9765625,
# Epoch 2, Iteration 16: Loss = 0.05424487218260765: Accuracy = 0.984375,
# Epoch 2, Iteration 17: Loss = 0.035819850862026215: Accuracy = 1.0,
# Epoch 2, Iteration 18: Loss = 0.13062185049057007: Accuracy = 0.96875,
# Epoch 2, Iteration 19: Loss = 0.0760648250579834: Accuracy = 0.9921875,
# Epoch 2, Iteration 20: Loss = 0.09907233715057373: Accuracy = 0.9765625,
# Epoch 2, Iteration 21: Loss = 0.1401635706424713: Accuracy = 0.9609375,
# Epoch 2, Iteration 22: Loss = 0.11217731982469559: Accuracy = 0.9609375,
# Epoch 2, Iteration 23: Loss = 0.1683294177055359: Accuracy = 0.96875,
# Epoch 2, Iteration 24: Loss = 0.0572047084569931: Accuracy = 1.0,
# Epoch 2, Iteration 25: Loss = 0.0792156234383583: Accuracy = 0.96875,
# Epoch 2, Iteration 26: Loss = 0.05713668465614319: Accuracy = 0.9921875,
# Epoch 2, Iteration 27: Loss = 0.09489201009273529: Accuracy = 0.984375,
# Epoch 2, Iteration 28: Loss = 0.07454092055559158: Accuracy = 0.9765625,
# Epoch 2, Iteration 29: Loss = 0.1476665586233139: Accuracy = 0.9609375,
# Epoch 2, Iteration 30: Loss = 0.06979725509881973: Accuracy = 0.9765625,
# Epoch 2, Iteration 31: Loss = 0.07313624024391174: Accuracy = 0.9765625,
# Epoch 2, Iteration 32: Loss = 0.08594854176044464: Accuracy = 0.984375,
# Epoch 2, Iteration 33: Loss = 0.08445344865322113: Accuracy = 0.984375,
# Epoch 2, Iteration 34: Loss = 0.0976390540599823: Accuracy = 0.9609375,
# Epoch 2, Iteration 35: Loss = 0.08691564202308655: Accuracy = 0.9921875,
# Epoch 2, Iteration 36: Loss = 0.06998923420906067: Accuracy = 0.9921875,
# Epoch 2, Iteration 37: Loss = 0.10669857263565063: Accuracy = 0.9765625,
# Epoch 2, Iteration 38: Loss = 0.08070911467075348: Accuracy = 0.9765625,
# Epoch 2, Iteration 39: Loss = 0.06870073825120926: Accuracy = 0.96875,
# Epoch 2, Iteration 40: Loss = 0.07373549044132233: Accuracy = 0.9921875,
# Epoch 2, Iteration 41: Loss = 0.04179071635007858: Accuracy = 0.9921875,
# Epoch 2, Iteration 42: Loss = 0.08628295361995697: Accuracy = 0.9765625,
# Epoch 2, Iteration 43: Loss = 0.07301145792007446: Accuracy = 0.9921875,
# Epoch 2, Iteration 44: Loss = 0.10102296620607376: Accuracy = 0.9765625,
# Epoch 2, Iteration 45: Loss = 0.09100575000047684: Accuracy = 0.9921875,
# Epoch 2, Iteration 46: Loss = 0.1100599467754364: Accuracy = 0.96875,
# Epoch 2, Iteration 47: Loss = 0.19171148538589478: Accuracy = 0.953125,
# Epoch 2, Iteration 48: Loss = 0.06967255473136902: Accuracy = 0.9765625,
# Epoch 2, Iteration 49: Loss = 0.043292220681905746: Accuracy = 1.0,
# Epoch 2, Iteration 50: Loss = 0.08303582668304443: Accuracy = 0.96875,
# Epoch 2, Iteration 51: Loss = 0.11385147273540497: Accuracy = 0.9609375,
# Epoch 2, Iteration 52: Loss = 0.05944548174738884: Accuracy = 0.9921875,
# Epoch 2, Iteration 53: Loss = 0.12335200607776642: Accuracy = 0.9765625,
# Epoch 2, Iteration 54: Loss = 0.07208555936813354: Accuracy = 0.9765625,
# Epoch 2, Iteration 55: Loss = 0.06492170691490173: Accuracy = 0.9921875,
# Epoch 2, Iteration 56: Loss = 0.13039197027683258: Accuracy = 0.96875,
# Epoch 2, Iteration 57: Loss = 0.12607015669345856: Accuracy = 0.953125,
# Epoch 2, Iteration 58: Loss = 0.10763224959373474: Accuracy = 0.96875,
# Epoch 2, Iteration 59: Loss = 0.09920608997344971: Accuracy = 0.9765625,
# Epoch 2, Iteration 60: Loss = 0.07405225932598114: Accuracy = 0.96875,
# Epoch 2, Iteration 61: Loss = 0.08461904525756836: Accuracy = 0.9765625,
# Epoch 2, Iteration 62: Loss = 0.07470846176147461: Accuracy = 0.9921875,
# Epoch 2, Iteration 63: Loss = 0.058394137769937515: Accuracy = 0.9765625,
# Epoch 2, Iteration 64: Loss = 0.07405034452676773: Accuracy = 0.984375,
# Epoch 2, Iteration 65: Loss = 0.041683562099933624: Accuracy = 1.0,
# Epoch 2, Iteration 66: Loss = 0.14114300906658173: Accuracy = 0.953125,
# Epoch 2, Iteration 67: Loss = 0.09787443280220032: Accuracy = 0.9765625,
# Epoch 2, Iteration 68: Loss = 0.059808384627103806: Accuracy = 0.9921875,
# Epoch 2, Iteration 69: Loss = 0.06514560431241989: Accuracy = 0.984375,
# Epoch 2, Iteration 70: Loss = 0.08304011821746826: Accuracy = 0.984375,
# Epoch 2, Iteration 71: Loss = 0.09968578070402145: Accuracy = 0.9765625,
# Epoch 2, Iteration 72: Loss = 0.06940511614084244: Accuracy = 0.9765625,
# Epoch 2, Iteration 73: Loss = 0.047120317816734314: Accuracy = 0.984375,
# Epoch 2, Iteration 74: Loss = 0.15705136954784393: Accuracy = 0.96875,
# Epoch 2, Iteration 75: Loss = 0.05685069411993027: Accuracy = 0.9921875,
# Epoch 2, Iteration 76: Loss = 0.13339805603027344: Accuracy = 0.9765625,
# Epoch 2, Iteration 77: Loss = 0.07639012485742569: Accuracy = 0.9609375,
# Epoch 2, Iteration 78: Loss = 0.04975535348057747: Accuracy = 0.9921875,
# Epoch 2, Iteration 79: Loss = 0.09735139459371567: Accuracy = 0.96875,
# Epoch 3, Iteration 1: Loss = 0.053742989897727966: Accuracy = 0.9921875,
# Epoch 3, Iteration 2: Loss = 0.050568222999572754: Accuracy = 0.9921875,
# Epoch 3, Iteration 3: Loss = 0.0856146514415741: Accuracy = 0.984375,
# Epoch 3, Iteration 4: Loss = 0.032752297818660736: Accuracy = 1.0,
# Epoch 3, Iteration 5: Loss = 0.025549428537487984: Accuracy = 0.9921875,
# Epoch 3, Iteration 6: Loss = 0.04180186986923218: Accuracy = 1.0,
# Epoch 3, Iteration 7: Loss = 0.07328735291957855: Accuracy = 0.984375,
# Epoch 3, Iteration 8: Loss = 0.13128191232681274: Accuracy = 0.9765625,
# Epoch 3, Iteration 9: Loss = 0.09073131531476974: Accuracy = 0.953125,
# Epoch 3, Iteration 10: Loss = 0.032396335154771805: Accuracy = 0.9921875,
# Epoch 3, Iteration 11: Loss = 0.03780941665172577: Accuracy = 0.9921875,
# Epoch 3, Iteration 12: Loss = 0.06885440647602081: Accuracy = 0.96875,
# Epoch 3, Iteration 13: Loss = 0.06898189336061478: Accuracy = 0.9921875,
# Epoch 3, Iteration 14: Loss = 0.08543752133846283: Accuracy = 0.9921875,
# Epoch 3, Iteration 15: Loss = 0.08037315309047699: Accuracy = 0.9921875,
# Epoch 3, Iteration 16: Loss = 0.061470843851566315: Accuracy = 0.9765625,
# Epoch 3, Iteration 17: Loss = 0.10682455450296402: Accuracy = 0.984375,
# Epoch 3, Iteration 18: Loss = 0.04246126115322113: Accuracy = 0.984375,
# Epoch 3, Iteration 19: Loss = 0.04026193171739578: Accuracy = 1.0,
# Epoch 3, Iteration 20: Loss = 0.02058909647166729: Accuracy = 1.0,
# Epoch 3, Iteration 21: Loss = 0.03606424853205681: Accuracy = 0.9921875,
# Epoch 3, Iteration 22: Loss = 0.030468717217445374: Accuracy = 0.9921875,
# Epoch 3, Iteration 23: Loss = 0.08929004520177841: Accuracy = 0.984375,
# Epoch 3, Iteration 24: Loss = 0.03917832672595978: Accuracy = 0.984375,
# Epoch 3, Iteration 25: Loss = 0.05343233421444893: Accuracy = 0.984375,
# Epoch 3, Iteration 26: Loss = 0.028209589421749115: Accuracy = 1.0,
# Epoch 3, Iteration 27: Loss = 0.057702213525772095: Accuracy = 0.984375,
# Epoch 3, Iteration 28: Loss = 0.05987422168254852: Accuracy = 0.9921875,
# Epoch 3, Iteration 29: Loss = 0.09155711531639099: Accuracy = 0.984375,
# Epoch 3, Iteration 30: Loss = 0.05487734079360962: Accuracy = 0.9765625,
# Epoch 3, Iteration 31: Loss = 0.06778834760189056: Accuracy = 0.9765625,
# Epoch 3, Iteration 32: Loss = 0.07248468697071075: Accuracy = 0.984375,
# Epoch 3, Iteration 33: Loss = 0.06965045630931854: Accuracy = 0.984375,
# Epoch 3, Iteration 34: Loss = 0.021215401589870453: Accuracy = 1.0,
# Epoch 3, Iteration 35: Loss = 0.034555770456790924: Accuracy = 1.0,
# Epoch 3, Iteration 36: Loss = 0.11819317191839218: Accuracy = 0.96875,
# Epoch 3, Iteration 37: Loss = 0.08777039498090744: Accuracy = 0.9765625,
# Epoch 3, Iteration 38: Loss = 0.06194177269935608: Accuracy = 0.984375,
# Epoch 3, Iteration 39: Loss = 0.08349940180778503: Accuracy = 0.984375,
# Epoch 3, Iteration 40: Loss = 0.06257133930921555: Accuracy = 0.984375,
# Epoch 3, Iteration 41: Loss = 0.027008913457393646: Accuracy = 1.0,
# Epoch 3, Iteration 42: Loss = 0.03295854479074478: Accuracy = 0.9921875,
# Epoch 3, Iteration 43: Loss = 0.0740494504570961: Accuracy = 0.9765625,
# Epoch 3, Iteration 44: Loss = 0.03226102516055107: Accuracy = 1.0,
# Epoch 3, Iteration 45: Loss = 0.04658660292625427: Accuracy = 0.9921875,
# Epoch 3, Iteration 46: Loss = 0.08198004961013794: Accuracy = 0.9765625,
# Epoch 3, Iteration 47: Loss = 0.04833158478140831: Accuracy = 0.9921875,
# Epoch 3, Iteration 48: Loss = 0.05930151790380478: Accuracy = 0.96875,
# Epoch 3, Iteration 49: Loss = 0.08077605068683624: Accuracy = 0.9609375,
# Epoch 3, Iteration 50: Loss = 0.08530004322528839: Accuracy = 0.9765625,
# Epoch 3, Iteration 51: Loss = 0.07241190969944: Accuracy = 0.9765625,
# Epoch 3, Iteration 52: Loss = 0.024299247190356255: Accuracy = 1.0,
# Epoch 3, Iteration 53: Loss = 0.027883481234312057: Accuracy = 1.0,
# Epoch 3, Iteration 54: Loss = 0.05473963916301727: Accuracy = 0.9765625,
# Epoch 3, Iteration 55: Loss = 0.08182111382484436: Accuracy = 0.9921875,
# Epoch 3, Iteration 56: Loss = 0.03927689790725708: Accuracy = 0.9921875,
# Epoch 3, Iteration 57: Loss = 0.03558977320790291: Accuracy = 1.0,
# Epoch 3, Iteration 58: Loss = 0.02994602918624878: Accuracy = 0.9921875,
# Epoch 3, Iteration 59: Loss = 0.03715978562831879: Accuracy = 1.0,
# Epoch 3, Iteration 60: Loss = 0.08287553489208221: Accuracy = 0.984375,
# Epoch 3, Iteration 61: Loss = 0.04922633618116379: Accuracy = 0.984375,
# Epoch 3, Iteration 62: Loss = 0.051515594124794006: Accuracy = 0.9921875,
# Epoch 3, Iteration 63: Loss = 0.04764653742313385: Accuracy = 0.984375,
# Epoch 3, Iteration 64: Loss = 0.07001650333404541: Accuracy = 0.96875,
# Epoch 3, Iteration 65: Loss = 0.042090605944395065: Accuracy = 0.9921875,
# Epoch 3, Iteration 66: Loss = 0.012714813463389874: Accuracy = 1.0,
# Epoch 3, Iteration 67: Loss = 0.03387974947690964: Accuracy = 0.9921875,
# Epoch 3, Iteration 68: Loss = 0.09580637514591217: Accuracy = 0.9765625,
# Epoch 3, Iteration 69: Loss = 0.05686026066541672: Accuracy = 0.9921875,
# Epoch 3, Iteration 70: Loss = 0.04475613683462143: Accuracy = 0.9921875,
# Epoch 3, Iteration 71: Loss = 0.05044141411781311: Accuracy = 0.984375,
# Epoch 3, Iteration 72: Loss = 0.14096227288246155: Accuracy = 0.9609375,
# Epoch 3, Iteration 73: Loss = 0.0222163088619709: Accuracy = 1.0,
# Epoch 3, Iteration 74: Loss = 0.06528367102146149: Accuracy = 0.96875,
# Epoch 3, Iteration 75: Loss = 0.035424310714006424: Accuracy = 0.9921875,
# Epoch 3, Iteration 76: Loss = 0.05508320778608322: Accuracy = 0.9765625,
# Epoch 3, Iteration 77: Loss = 0.03314390778541565: Accuracy = 0.9921875,
# Epoch 3, Iteration 78: Loss = 0.12005525827407837: Accuracy = 0.9609375,
# Epoch 3, Iteration 79: Loss = 0.1348949372768402: Accuracy = 0.96875,
# Epoch 4, Iteration 1: Loss = 0.04887482523918152: Accuracy = 0.984375,
# Epoch 4, Iteration 2: Loss = 0.03360951691865921: Accuracy = 1.0,
# Epoch 4, Iteration 3: Loss = 0.053485527634620667: Accuracy = 0.984375,
# Epoch 4, Iteration 4: Loss = 0.02724834345281124: Accuracy = 1.0,
# Epoch 4, Iteration 5: Loss = 0.05380755290389061: Accuracy = 0.9921875,
# Epoch 4, Iteration 6: Loss = 0.028594236820936203: Accuracy = 0.9921875,
# Epoch 4, Iteration 7: Loss = 0.028827901929616928: Accuracy = 1.0,
# Epoch 4, Iteration 8: Loss = 0.013513396494090557: Accuracy = 1.0,
# Epoch 4, Iteration 9: Loss = 0.03226679563522339: Accuracy = 1.0,
# Epoch 4, Iteration 10: Loss = 0.02278919517993927: Accuracy = 1.0,
# Epoch 4, Iteration 11: Loss = 0.06809227168560028: Accuracy = 0.984375,
# Epoch 4, Iteration 12: Loss = 0.024663252755999565: Accuracy = 0.9921875,
# Epoch 4, Iteration 13: Loss = 0.0344134196639061: Accuracy = 0.9921875,
# Epoch 4, Iteration 14: Loss = 0.07238472998142242: Accuracy = 0.9765625,
# Epoch 4, Iteration 15: Loss = 0.01904137060046196: Accuracy = 1.0,
# Epoch 4, Iteration 16: Loss = 0.03344889357686043: Accuracy = 1.0,
# Epoch 4, Iteration 17: Loss = 0.1027422845363617: Accuracy = 0.9765625,
# Epoch 4, Iteration 18: Loss = 0.01862967759370804: Accuracy = 0.9921875,
# Epoch 4, Iteration 19: Loss = 0.0444352924823761: Accuracy = 0.9921875,
# Epoch 4, Iteration 20: Loss = 0.03640029579401016: Accuracy = 0.9921875,
# Epoch 4, Iteration 21: Loss = 0.08260180056095123: Accuracy = 0.984375,
# Epoch 4, Iteration 22: Loss = 0.03256092965602875: Accuracy = 0.984375,
# Epoch 4, Iteration 23: Loss = 0.03284446895122528: Accuracy = 1.0,
# Epoch 4, Iteration 24: Loss = 0.019488409161567688: Accuracy = 1.0,
# Epoch 4, Iteration 25: Loss = 0.023693613708019257: Accuracy = 1.0,
# Epoch 4, Iteration 26: Loss = 0.012090256437659264: Accuracy = 1.0,
# Epoch 4, Iteration 27: Loss = 0.03751261159777641: Accuracy = 0.984375,
# Epoch 4, Iteration 28: Loss = 0.025221306830644608: Accuracy = 1.0,
# Epoch 4, Iteration 29: Loss = 0.01544294785708189: Accuracy = 1.0,
# Epoch 4, Iteration 30: Loss = 0.04876824840903282: Accuracy = 0.9921875,
# Epoch 4, Iteration 31: Loss = 0.031644921749830246: Accuracy = 0.9921875,
# Epoch 4, Iteration 32: Loss = 0.06913734972476959: Accuracy = 0.984375,
# Epoch 4, Iteration 33: Loss = 0.03675712272524834: Accuracy = 0.9921875,
# Epoch 4, Iteration 34: Loss = 0.04877982288599014: Accuracy = 0.9921875,
# Epoch 4, Iteration 35: Loss = 0.020660199224948883: Accuracy = 1.0,
# Epoch 4, Iteration 36: Loss = 0.028709571808576584: Accuracy = 1.0,
# Epoch 4, Iteration 37: Loss = 0.023723434656858444: Accuracy = 1.0,
# Epoch 4, Iteration 38: Loss = 0.03349559009075165: Accuracy = 0.9921875,
# Epoch 4, Iteration 39: Loss = 0.019846748560667038: Accuracy = 1.0,
# Epoch 4, Iteration 40: Loss = 0.06416162103414536: Accuracy = 0.9921875,
# Epoch 4, Iteration 41: Loss = 0.058634232729673386: Accuracy = 0.9765625,
# Epoch 4, Iteration 42: Loss = 0.027705714106559753: Accuracy = 1.0,
# Epoch 4, Iteration 43: Loss = 0.0693117156624794: Accuracy = 0.984375,
# Epoch 4, Iteration 44: Loss = 0.0950661450624466: Accuracy = 0.9765625,
# Epoch 4, Iteration 45: Loss = 0.03438156843185425: Accuracy = 0.9921875,
# Epoch 4, Iteration 46: Loss = 0.03350243717432022: Accuracy = 0.9921875,
# Epoch 4, Iteration 47: Loss = 0.02333494834601879: Accuracy = 1.0,
# Epoch 4, Iteration 48: Loss = 0.025599487125873566: Accuracy = 1.0,
# Epoch 4, Iteration 49: Loss = 0.029842164367437363: Accuracy = 1.0,
# Epoch 4, Iteration 50: Loss = 0.08649766445159912: Accuracy = 0.9765625,
# Epoch 4, Iteration 51: Loss = 0.09296654164791107: Accuracy = 0.984375,
# Epoch 4, Iteration 52: Loss = 0.02312014251947403: Accuracy = 1.0,
# Epoch 4, Iteration 53: Loss = 0.03854874148964882: Accuracy = 0.9921875,
# Epoch 4, Iteration 54: Loss = 0.0653933733701706: Accuracy = 0.984375,
# Epoch 4, Iteration 55: Loss = 0.05071696266531944: Accuracy = 0.9921875,
# Epoch 4, Iteration 56: Loss = 0.016689147800207138: Accuracy = 1.0,
# Epoch 4, Iteration 57: Loss = 0.031593240797519684: Accuracy = 0.9921875,
# Epoch 4, Iteration 58: Loss = 0.08768600225448608: Accuracy = 0.9609375,
# Epoch 4, Iteration 59: Loss = 0.019814757630228996: Accuracy = 0.9921875,
# Epoch 4, Iteration 60: Loss = 0.011186120100319386: Accuracy = 1.0,
# Epoch 4, Iteration 61: Loss = 0.04599921405315399: Accuracy = 0.9921875,
# Epoch 4, Iteration 62: Loss = 0.057894088327884674: Accuracy = 0.96875,
# Epoch 4, Iteration 63: Loss = 0.036721229553222656: Accuracy = 0.9921875,
# Epoch 4, Iteration 64: Loss = 0.04524575173854828: Accuracy = 0.984375,
# Epoch 4, Iteration 65: Loss = 0.054442599415779114: Accuracy = 0.984375,
# Epoch 4, Iteration 66: Loss = 0.027307730168104172: Accuracy = 0.9921875,
# Epoch 4, Iteration 67: Loss = 0.021786294877529144: Accuracy = 1.0,
# Epoch 4, Iteration 68: Loss = 0.05942411348223686: Accuracy = 0.984375,
# Epoch 4, Iteration 69: Loss = 0.03021763637661934: Accuracy = 0.9921875,
# Epoch 4, Iteration 70: Loss = 0.09044253081083298: Accuracy = 0.9921875,
# Epoch 4, Iteration 71: Loss = 0.023002248257398605: Accuracy = 1.0,
# Epoch 4, Iteration 72: Loss = 0.03802959993481636: Accuracy = 0.9921875,
# Epoch 4, Iteration 73: Loss = 0.029242662712931633: Accuracy = 0.9921875,
# Epoch 4, Iteration 74: Loss = 0.02531714364886284: Accuracy = 0.9921875,
# Epoch 4, Iteration 75: Loss = 0.025173582136631012: Accuracy = 1.0,
# Epoch 4, Iteration 76: Loss = 0.05157093331217766: Accuracy = 0.9765625,
# Epoch 4, Iteration 77: Loss = 0.08509325981140137: Accuracy = 0.9765625,
# Epoch 4, Iteration 78: Loss = 0.024073872715234756: Accuracy = 0.9921875,
# Epoch 4, Iteration 79: Loss = 0.017461039125919342: Accuracy = 1.0,
# Epoch 5, Iteration 1: Loss = 0.02329273521900177: Accuracy = 1.0,
# Epoch 5, Iteration 2: Loss = 0.04092126339673996: Accuracy = 0.9921875,
# Epoch 5, Iteration 3: Loss = 0.010472392663359642: Accuracy = 1.0,
# Epoch 5, Iteration 4: Loss = 0.014722762629389763: Accuracy = 1.0,
# Epoch 5, Iteration 5: Loss = 0.02799108251929283: Accuracy = 1.0,
# Epoch 5, Iteration 6: Loss = 0.013306432403624058: Accuracy = 0.9921875,
# Epoch 5, Iteration 7: Loss = 0.03320187330245972: Accuracy = 0.984375,
# Epoch 5, Iteration 8: Loss = 0.013377908617258072: Accuracy = 1.0,
# Epoch 5, Iteration 9: Loss = 0.03742678463459015: Accuracy = 0.984375,
# Epoch 5, Iteration 10: Loss = 0.03872603550553322: Accuracy = 0.984375,
# Epoch 5, Iteration 11: Loss = 0.03726023808121681: Accuracy = 0.9921875,
# Epoch 5, Iteration 12: Loss = 0.02981799654662609: Accuracy = 0.9921875,
# Epoch 5, Iteration 13: Loss = 0.02240326628088951: Accuracy = 0.9921875,
# Epoch 5, Iteration 14: Loss = 0.016644079238176346: Accuracy = 1.0,
# Epoch 5, Iteration 15: Loss = 0.029562214389443398: Accuracy = 0.9921875,
# Epoch 5, Iteration 16: Loss = 0.023325879126787186: Accuracy = 1.0,
# Epoch 5, Iteration 17: Loss = 0.02091088518500328: Accuracy = 1.0,
# Epoch 5, Iteration 18: Loss = 0.019071953371167183: Accuracy = 1.0,
# Epoch 5, Iteration 19: Loss = 0.019525889307260513: Accuracy = 1.0,
# Epoch 5, Iteration 20: Loss = 0.015419114381074905: Accuracy = 1.0,
# Epoch 5, Iteration 21: Loss = 0.030534012243151665: Accuracy = 1.0,
# Epoch 5, Iteration 22: Loss = 0.07865666598081589: Accuracy = 0.9765625,
# Epoch 5, Iteration 23: Loss = 0.018653251230716705: Accuracy = 1.0,
# Epoch 5, Iteration 24: Loss = 0.021227644756436348: Accuracy = 1.0,
# Epoch 5, Iteration 25: Loss = 0.073563352227211: Accuracy = 0.984375,
# Epoch 5, Iteration 26: Loss = 0.04783559963107109: Accuracy = 0.9921875,
# Epoch 5, Iteration 27: Loss = 0.022604700177907944: Accuracy = 1.0,
# Epoch 5, Iteration 28: Loss = 0.024203818291425705: Accuracy = 0.9921875,
# Epoch 5, Iteration 29: Loss = 0.01469473633915186: Accuracy = 0.9921875,
# Epoch 5, Iteration 30: Loss = 0.016108695417642593: Accuracy = 1.0,
# Epoch 5, Iteration 31: Loss = 0.0289419237524271: Accuracy = 0.9921875,
# Epoch 5, Iteration 32: Loss = 0.017893318086862564: Accuracy = 1.0,
# Epoch 5, Iteration 33: Loss = 0.03170913830399513: Accuracy = 0.9921875,
# Epoch 5, Iteration 34: Loss = 0.026888318359851837: Accuracy = 0.9921875,
# Epoch 5, Iteration 35: Loss = 0.04243655130267143: Accuracy = 0.9765625,
# Epoch 5, Iteration 36: Loss = 0.02508264034986496: Accuracy = 0.9921875,
# Epoch 5, Iteration 37: Loss = 0.013386400416493416: Accuracy = 1.0,
# Epoch 5, Iteration 38: Loss = 0.01917935162782669: Accuracy = 1.0,
# Epoch 5, Iteration 39: Loss = 0.03023700974881649: Accuracy = 0.9921875,
# Epoch 5, Iteration 40: Loss = 0.01715393178164959: Accuracy = 1.0,
# Epoch 5, Iteration 41: Loss = 0.06278291344642639: Accuracy = 0.9921875,
# Epoch 5, Iteration 42: Loss = 0.059121273458004: Accuracy = 0.9921875,
# Epoch 5, Iteration 43: Loss = 0.08499185740947723: Accuracy = 0.9921875,
# Epoch 5, Iteration 44: Loss = 0.024182824417948723: Accuracy = 1.0,
# Epoch 5, Iteration 45: Loss = 0.029153533279895782: Accuracy = 0.9921875,
# Epoch 5, Iteration 46: Loss = 0.011387167498469353: Accuracy = 1.0,
# Epoch 5, Iteration 47: Loss = 0.03277025371789932: Accuracy = 0.984375,
# Epoch 5, Iteration 48: Loss = 0.015419550240039825: Accuracy = 1.0,
# Epoch 5, Iteration 49: Loss = 0.042864713817834854: Accuracy = 0.984375,
# Epoch 5, Iteration 50: Loss = 0.038883380591869354: Accuracy = 0.9921875,
# Epoch 5, Iteration 51: Loss = 0.012229057028889656: Accuracy = 1.0,
# Epoch 5, Iteration 52: Loss = 0.028638383373618126: Accuracy = 0.9921875,
# Epoch 5, Iteration 53: Loss = 0.015121844597160816: Accuracy = 1.0,
# Epoch 5, Iteration 54: Loss = 0.02257792092859745: Accuracy = 1.0,
# Epoch 5, Iteration 55: Loss = 0.019555361941456795: Accuracy = 1.0,
# Epoch 5, Iteration 56: Loss = 0.017780238762497902: Accuracy = 0.9921875,
# Epoch 5, Iteration 57: Loss = 0.0461646169424057: Accuracy = 0.9921875,
# Epoch 5, Iteration 58: Loss = 0.028626279905438423: Accuracy = 0.9921875,
# Epoch 5, Iteration 59: Loss = 0.018062300980091095: Accuracy = 1.0,
# Epoch 5, Iteration 60: Loss = 0.04480970650911331: Accuracy = 0.984375,
# Epoch 5, Iteration 61: Loss = 0.02042689174413681: Accuracy = 1.0,
# Epoch 5, Iteration 62: Loss = 0.021253857761621475: Accuracy = 0.9921875,
# Epoch 5, Iteration 63: Loss = 0.05461304634809494: Accuracy = 0.984375,
# Epoch 5, Iteration 64: Loss = 0.06032551825046539: Accuracy = 0.984375,
# Epoch 5, Iteration 65: Loss = 0.03238958492875099: Accuracy = 1.0,
# Epoch 5, Iteration 66: Loss = 0.016464153304696083: Accuracy = 0.9921875,
# Epoch 5, Iteration 67: Loss = 0.04953490570187569: Accuracy = 0.9921875,
# Epoch 5, Iteration 68: Loss = 0.02570219524204731: Accuracy = 1.0,
# Epoch 5, Iteration 69: Loss = 0.028952203691005707: Accuracy = 0.984375,
# Epoch 5, Iteration 70: Loss = 0.0406794473528862: Accuracy = 0.984375,
# Epoch 5, Iteration 71: Loss = 0.028257746249437332: Accuracy = 0.9921875,
# Epoch 5, Iteration 72: Loss = 0.013848910108208656: Accuracy = 1.0,
# Epoch 5, Iteration 73: Loss = 0.08306512236595154: Accuracy = 0.984375,
# Epoch 5, Iteration 74: Loss = 0.04581015184521675: Accuracy = 0.9921875,
# Epoch 5, Iteration 75: Loss = 0.021820418536663055: Accuracy = 0.9921875,
# Epoch 5, Iteration 76: Loss = 0.014655325561761856: Accuracy = 1.0,
# Epoch 5, Iteration 77: Loss = 0.011464237235486507: Accuracy = 1.0,
# Epoch 5, Iteration 78: Loss = 0.017596617341041565: Accuracy = 1.0,
# Epoch 5, Iteration 79: Loss = 0.01767193153500557: Accuracy = 1.0,

# %%
from resnet50Pytorch import AnimalClassifier  # Import the AnimalClassifier class from the resnet50Pytorch module

network = AnimalClassifier()  # Create an instance of the AnimalClassifier

path = "../data/images/scoiattolo/"  # You could change "cavallo" to any animal from data/images or may be set path to your own data

# Iterate over the images in the directory
for animal in os.listdir(path):
    print(network(path + animal))  # Print the result of classifying each image using the AnimalClassifier
# Out:
# squirrel
# squirrel
# squirrel
# squirrel
# squirrel
# squirrel
# squirrel
# squirrel
# squirrel
# squirrel
# squirrel
# squirrel
# squirrel
# squirrel
# squirrel
# squirrel
# squirrel
# squirrel
# squirrel
# squirrel
# squirrel
# squirrel
# squirrel
# squirrel
# squirrel
# squirrel
# squirrel
# squirrel
# dog
# squirrel
# squirrel
# squirrel
